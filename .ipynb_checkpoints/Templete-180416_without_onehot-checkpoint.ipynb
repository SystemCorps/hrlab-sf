# %% [markdown]
# # CNN Trainig Templete
# ## Based on Tensorlfow - CNN MNIST example
# https://github.com/tensorflow/tensorflow/blob/r1.6/tensorflow/examples/tutorials/layers/cnn_mnist.py

# %% [markdown]
# ## 필요한 library 호출

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf

import cv2

import os

tf.logging.set_verbosity(tf.logging.INFO)
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## CNN model 설계
# 현재는 MNIST에 사용된 것으로, 추후 그물 찢김에 적용하기 위해 수정 필요
#
# ### Input Layer
# Input Image Pixel: 28x28
# Color channel: 1 (grayscale)
#
# ### 1st Conv Layer
# Num of filter: 32
# Kernel size: 5x5
# Padding: Same
# Activation: ReLU
# Padding same은 입/출력이 같은 크기를 갖도록 padding하는 것
#
# ### 1st Pooling Layer
# Max pooling
# Size: 2x2
# Stride: 2
# Max pooling 시 size의 폭과 stride가 같으면 pooling window가 서로 겹치지 않음
#
# ### 2nd Conv Layer
# Num of filter: 64
# Kernel size: 5x5
# Padding: Same
# Activation: ReLU
#
# ### 2nd Pooling Layer
# Max pooling
# Size: 2x2
# Stride: 2
#
#
# ### 3rd, 4th, 5th
#
#
# ### Dense Layer
# Fully connected
#
# ### Drop out
# Rate: 0.4 (40%)
# 훈련 중 40%의 connection이 임의로 제거됨
# Overfitting 방지
# 뇌의학에서도 학습을 반복할수록 사람 뇌의 뉴런은 일부 connection이 끊어지면서 더 확실하게 학습한다고 함
#
# ### Logits Layer
# Binaray classification
#
# ### Training
# Loss function: Softmax Cross Entropy
# Optimizer: Gradient Descent
# Learning rate: 0.001

# %%
def cnn_model_fn(features, labels, mode):
    
    """Model function for CNN."""
    # Input Layer
    # Reshape X to 4-D tensor: [batch_size, height, width, channels]
    # Our Fishing net image size is 640x480 and 3-channel (RGB)
    input_layer = tf.reshape(features["x"], [-1, 480, 640, 3])

    # Convolutional Layer #1
    # Computes 48 features using a 5x5 filter with ReLU activation.
    # Padding is added to preserve width and height.
    # Input Tensor Shape: [batch_size, 480, 640, 3]
    # Output Tensor Shape: [batch_size, 480, 640, 48]
    conv1 = tf.layers.conv2d(
        
        inputs=input_layer,
        filters=48,
        kernel_size=[5, 5],
        padding="same",
        activation=tf.nn.relu)
    print(conv1.shape)

    # Pooling Layer #1
    # First max pooling layer with a 2x2 filter and stride of 2
    # Input Tensor Shape: [batch_size, 480, 640, 48]
    # Output Tensor Shape: [batch_size, 240, 320, 48]
    pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)
    print(pool1.shape)

    # Convolutional Layer #2
    # Computes 96 features using a 5x5 filter.
    # Padding is added to preserve width and height.
    # Input Tensor Shape: [batch_size, 240, 320, 48]
    # Output Tensor Shape: [batch_size, 240, 320, 96]
    conv2 = tf.layers.conv2d(
        inputs=pool1,
        filters=96,
        kernel_size=[5, 5],
        padding="same",
        activation=tf.nn.relu)
    print(conv2.shape)

    # Pooling Layer #2
    # Second max pooling layer with a 2x2 filter and stride of 2
    # Input Tensor Shape: [batch_size, 240, 320, 96]
    # Output Tensor Shape: [batch_size, 120, 160, 96]
    pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)
    print(pool2.shape)

    
    
    
    # Input Tensor Shape: [batch_size, 120, 160, 96]
    # Output Tensor Shape: [batch_size, 120, 160, 96]    
    conv3 = tf.layers.conv2d(
        inputs=pool2,
        filters=96,
        kernel_size=[5, 5],
        padding="same",
        activation=tf.nn.relu)
    print(conv3.shape)
    
    # Input Tensor Shape: [batch_size, 120, 160, 96]
    # Output Tensor Shape: [batch_size, 60, 80, 96]
    pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=[2, 2], strides=2)
    print(pool3.shape)
    
    
    
    # Input Tensor Shape: [batch_size, 60, 80, 96]
    # Output Tensor Shape: [batch_size, 60, 80, 96]    
    conv4 = tf.layers.conv2d(
        inputs=pool3,
        filters=96,
        kernel_size=[5, 5],
        padding="same",
        activation=tf.nn.relu)
    print(conv4.shape)
    
    # Input Tensor Shape: [batch_size, 60, 80, 96]
    # Output Tensor Shape: [batch_size, 30, 40, 96]
    pool4 = tf.layers.max_pooling2d(inputs=conv4, pool_size=[2, 2], strides=2)
    print(pool4.shape)
    
    
    
    # Input Tensor Shape: [batch_size, 30, 40, 96]
    # Output Tensor Shape: [batch_size, 30, 40, 96]    
    conv5 = tf.layers.conv2d(
        inputs=pool4,
        filters=96,
        kernel_size=[5, 5],
        padding="same",
        activation=tf.nn.relu)
    print(conv5.shape)
    
    # Input Tensor Shape: [batch_size, 30, 40, 96]
    # Output Tensor Shape: [batch_size, 15, 20, 96]
    pool5 = tf.layers.max_pooling2d(inputs=conv5, pool_size=[2, 2], strides=2)
    print(pool5.shape)
    
    
    
    
    # Flatten tensor into a batch of vectors
    # Input Tensor Shape: [batch_size, 15, 20, 96]
    # Output Tensor Shape: [batch_size, 15 * 20 * 96]
    pool5_flat = tf.reshape(pool5, [-1, 15 * 20 * 96])
    print(pool5_flat.shape)


    # Dense Layer
    # Densely connected layer with 1024 neurons
    # Input Tensor Shape: [batch_size, 15 * 20 * 96]
    # Output Tensor Shape: [batch_size, 1024]
    dense = tf.layers.dense(inputs=pool5_flat, units=1024, activation=tf.nn.relu)
    print(dense.shape)

    # Add dropout operation; 0.6 probability that element will be kept
    dropout = tf.layers.dropout(
        inputs=dense, rate=0.4, training=mode == tf.estimator.ModeKeys.TRAIN)

    # Logits layer
    # Input Tensor Shape: [batch_size, 1024]
    # Output Tensor Shape: [batch_size, 1]
    logits = tf.layers.dense(inputs=dropout, units=2)
    print(logits.shape)

    predictions = {
        # Generate predictions (for PREDICT and EVAL mode)
        "classes": tf.argmax(input=logits, axis=1),
        # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
        # `logging_hook`.
        "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
    }
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Calculate Loss (for both TRAIN and EVAL modes)
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
    # sparse_softmax_cross_entropy cannot use one-hot encoding
    
    #loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=labels, logits=logits)

    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {
        "accuracy": tf.metrics.accuracy(
            labels=labels, predictions=predictions["classes"])}
    return tf.estimator.EstimatorSpec(
        mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %% [markdown]
# ## Code Run
#
#
# ### Training
# Batch size: 128
# Epoch: 5
# Shuffle: True
# Step: 20000

# %% [markdown]
# ## Loading dataset
# Load dataset and split them into training data and evaluation data

# %%
# torn: 0-1484
# untorn: 0-1779
num_torn = 1485
num_untorn = 1780
total_pix = 480*640*3

torn_data = np.zeros((num_torn, total_pix), dtype=np.float32)
print(torn_data.shape)
untorn_data = np.zeros((num_untorn, total_pix), dtype=np.float32)
# Out:
# (1485, 921600)

# %%
torn_idx = np.arange(num_torn)
untorn_idx = np.arange(num_untorn)
print(torn_idx)

np.random.shuffle(torn_idx)
np.random.shuffle(untorn_idx)

print(torn_idx)
# Out:
# [   0    1    2 ... 1482 1483 1484]
# [ 475  509  320 ... 1430 1254  773]

# %%
for i in range(num_torn):
    img = cv2.imread("/dataset/torn/img-%04d.png" % torn_idx[i]).flatten()
    torn_data[i][:] = img

# %%
for i in range(num_untorn):
    img = cv2.imread("/dataset/untorn/img-%04d.png" % untorn_idx[i]).flatten()
    untorn_data[i][:] = img

# %%
torn_label = np.full((num_torn,1), 1, dtype=np.float32)
untorn_label = np.full((num_untorn,1), 1, dtype=np.float32)

# %%
# 80% training, 20% evaluation
tr_rate = 0.8
num_tr_torn = int(tr_rate * num_torn)
num_ev_torn = num_torn - num_tr_torn
print(num_tr_torn, num_ev_torn)

num_tr_untorn = int(tr_rate * num_untorn)
num_ev_untorn = num_untorn - num_tr_untorn
print(num_tr_untorn, num_ev_untorn)

tr_torn = torn_data[:num_tr_torn][:]
ev_torn = torn_data[num_tr_torn:][:]
print(tr_torn.shape)
print(ev_torn.shape)

tr_untorn = untorn_data[:num_tr_untorn][:]
ev_untorn = untorn_data[num_tr_untorn:][:]
print(tr_untorn.shape)
print(ev_untorn.shape)



tr_data = np.append(tr_torn, tr_untorn, axis=0)
print(tr_data.shape)
ev_data = np.append(ev_torn, ev_untorn, axis=0)
print(ev_data.shape)

tr_label = np.append(np.full((num_tr_torn), 1, dtype=np.int32), np.full((num_tr_untorn), 0, dtype=np.int32))
ev_label = np.append(np.full((num_ev_torn), 1, dtype=np.int32), np.full((num_ev_untorn), 0, dtype=np.int32))
print(tr_label.shape[0], ev_label.shape[0])
# Out:
# 1188 297
# 1424 356
# (1188, 921600)
# (297, 921600)
# (1424, 921600)
# (356, 921600)
# (2612, 921600)
# (653, 921600)
# 2612 653

# %%
shuf1 = np.arange(tr_label.shape[0])
np.random.shuffle(shuf1)
print(shuf1)

shuf2 = np.arange(ev_label.shape[0])
np.random.shuffle(shuf2)
print(shuf2)

tr_data_sh = np.zeros((tr_data.shape), dtype=np.float32)
tr_label_sh = np.zeros((tr_label.shape), dtype=np.int32)
ev_data_sh = np.zeros((ev_data.shape), dtype=np.float32)
ev_label_sh = np.zeros((ev_label.shape), dtype=np.int32)


for i in range(tr_label.shape[0]):
    tr_data_sh[i][:] = tr_data[shuf1[i]][:]
    tr_label_sh[i] = tr_label[shuf1[i]]
    
for i in range (ev_label.shape[0]):
    ev_data_sh[i][:] = ev_data[shuf2[i]][:]
    ev_label_sh[i] = ev_label[shuf2[i]]
# Out:
# [2209  515  497 ...  605 1572  308]
# [374 361 426 597  25 151 118 319 368 365 477 285  24 181 346 228 596 587
#  620 488 645 529 429  34 200 292 431 439 490  98 406 371 651 576 559 237
#  487  93 463 586  55 519 452 310 344 150  19 623 254 395  53 225  62  81
#  137 250 508 585 155 396  84  17 538  39 423 435 207 619 213 349 177  31
#  359 185 415  95 128 447 357 507 243 633 546  35  27 218 399 433 643 425
#  256 271 391 168 373 214 629 110 637 299  88  87 328 124 578 293  97 186
#  282 116 421 622 156 448 281 167 162 602 369 468 342 266 467 498 334 107
#  493 443 205 103 217 551 436 238 544 411  80 227 481  56  73 209 401 120
#  224 112 187 469 198 428 394  41 459 136 158 257 149 562 495 566   8 366
#  410 267 573  59  30 169 438 300 535 280  90 572  20 556 378 510 275  33
#   43 153 330 603 598 360 534  64 122 268 245 531 407 142 164  22 154 517
#   40 350  71 127 460  18 593  58 408 427 297 453  29 236 558 526 272 115
#  157 291 253 478 607 457 522 123 485 419 159 161 252  70 304 298 283  92
#  388  38 504 418 552 595 262 516 470 263 561 189  10  50 347 353 345 646
#  276 143 471   1 612 148 333 610 327 356   4 212 446  57 604 231 104 581
#  296 480 215 464 390 611  42 308 372 130 249 183 324 194 417 337 287 108
#  641 499 232 588 456 152   6 557  45 536 525  54 523 311 614 564 332 584
#  206 568 173 420 563 638 387 624   2 219 352 121 303 615 503 524 437 506
#   61  78 630  36   7 648 179 466 241 413 537 627 201 145 548  96 513 170
#  269 274 583 102 180 362 500 379 626 600 389 652 515 454 126 260 175 550
#  172 547 414 370 261 632  47 146 424 160 403 521   3  82 321 242 336 307
#  527 496  69 288 631  49  28 650  26 501 560 473 402  77 165 514  74 574
#  377  14 316 635 114 621 141 302 442 270 220 405  91 441 649 195 193 589
#  211 565 434 451 105 325  72 197 171 590 351 549 326 647 482 335 450 497
#  409 295 553 354  13 255 192 240 412 290 609   9  37 235 178 381 273 117
#  251 540 312 461 305 582  46 530 278 383 320 277 532 210  63 196 462 355
#  606 216  52 129 233  32 579 440 512 639 636 601 331 289  83 430 476 248
#  489 229 301 239 541 230 393 176 188 339 380 384 474 376 518 223 449  12
#  577  76 119  11 363 247 279  23 422 234 432 569 199 533 625 329 502 605
#  554 445 392 140 404 134 617 505 203  94 385 416 315 592 642  51 111 135
#   44 101 294 202 567 575 341 386 259 132 571   0 322 382 348 634 246 264
#  511 208 364 591 323 483 640 286 174 580 163 265 444 221  99   5  16  60
#  528 182 494 340 367 509 109 144 343 465 484 542 475 314 608 147 539 599
#  555 455 479 486 100  89  68  75 284  85 226  86  67 400 191 492 570 166
#  358 618 317 133 491 472 520 458 222 244 545  79 313 204 397 613 258 131
#   65  66 543 628 306 644 594 398 125 375  48 338 318 309 106 616 139 184
#   15  21 113 138 190]

# %%
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5
session = tf.Session(config=config)

# Create the Estimator
net_classifier = tf.estimator.Estimator(
    model_fn=cnn_model_fn, model_dir="/models/CNN2600")

# Set up logging for predictions
# Log the values in the "Softmax" tensor with label "probabilities"
tensors_to_log = {"probabilities": "softmax_tensor"}
logging_hook = tf.train.LoggingTensorHook(
    tensors=tensors_to_log, every_n_iter=50)

batch_s = 1
epochs = 5
tr_steps = int(tr_data.shape[0]/batch_s*epochs)
in_steps = 1

for d in ['/device:GPU:0', '/device:GPU:1']:
    with tf.device(d):

        # Train the model
        train_input_fn = tf.estimator.inputs.numpy_input_fn(
            x={"x": tr_data},
            y=tr_label,
            batch_size=batch_s,
            num_epochs=epochs,
            shuffle=True)
        net_classifier.train(
            input_fn=train_input_fn,
            steps=20000,
            hooks=[logging_hook])
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/models/CNN2600', '_save_checkpoints_steps': None, '_global_id_in_cluster': 0, '_session_config': None, '_keep_checkpoint_every_n_hours': 10000, '_is_chief': True, '_tf_random_seed': None, '_save_summary_steps': 100, '_master': '', '_num_ps_replicas': 0, '_evaluation_master': '', '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_task_type': 'worker', '_task_id': 0, '_save_checkpoints_secs': 600, '_service': None, '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0271019c88>}
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-52240
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 52241 into /models/CNN2600/model.ckpt.
# INFO:tensorflow:probabilities = [[0.44189933 0.55810064]]
# INFO:tensorflow:loss = 0.81667316, step = 52241
# INFO:tensorflow:probabilities = [[0.4535588 0.5464412]] (1.518 sec)
# INFO:tensorflow:global_step/sec: 34.4273
# INFO:tensorflow:probabilities = [[0.45761913 0.54238087]] (1.388 sec)
# INFO:tensorflow:loss = 0.781718, step = 52341 (2.906 sec)
# INFO:tensorflow:probabilities = [[0.4581787  0.54182136]] (1.444 sec)
# INFO:tensorflow:global_step/sec: 35.1825
# INFO:tensorflow:probabilities = [[0.45870495 0.5412951 ]] (1.398 sec)
# INFO:tensorflow:loss = 0.77934813, step = 52441 (2.842 sec)
# INFO:tensorflow:probabilities = [[0.5276401  0.47235987]] (1.406 sec)
# INFO:tensorflow:global_step/sec: 35.7331
# INFO:tensorflow:probabilities = [[0.5318935  0.46810648]] (1.392 sec)
# INFO:tensorflow:loss = 0.63131195, step = 64641 (2.799 sec)
# INFO:tensorflow:probabilities = [[0.5365016  0.46349838]] (1.390 sec)
# INFO:tensorflow:global_step/sec: 35.7119
# INFO:tensorflow:probabilities = [[0.5385448 0.4614553]] (1.410 sec)
# INFO:tensorflow:loss = 0.6188847, step = 64741 (2.801 sec)
# INFO:tensorflow:probabilities = [[0.5439701  0.45602983]] (1.385 sec)
# INFO:tensorflow:global_step/sec: 35.734
# INFO:tensorflow:probabilities = [[0.5438852  0.45611483]] (1.414 sec)
# INFO:tensorflow:loss = 0.60901713, step = 64841 (2.798 sec)
# INFO:tensorflow:probabilities = [[0.5491691 0.4508309]] (1.382 sec)
# INFO:tensorflow:global_step/sec: 35.8563
# INFO:tensorflow:probabilities = [[0.55381083 0.4461892 ]] (1.407 sec)
# INFO:tensorflow:loss = 0.59093213, step = 64941 (2.790 sec)
# INFO:tensorflow:probabilities = [[0.55689377 0.44310626]] (1.387 sec)
# INFO:tensorflow:global_step/sec: 35.7185
# INFO:tensorflow:probabilities = [[0.56039613 0.4396039 ]] (1.413 sec)
# INFO:tensorflow:loss = 0.5791114, step = 65041 (2.800 sec)
# INFO:tensorflow:probabilities = [[0.5642774 0.4357226]] (1.403 sec)
# INFO:tensorflow:global_step/sec: 35.7212
# INFO:tensorflow:probabilities = [[0.5666177 0.4333823]] (1.396 sec)
# INFO:tensorflow:loss = 0.836135, step = 65141 (2.798 sec)
# INFO:tensorflow:probabilities = [[0.5698336  0.43016642]] (1.420 sec)
# INFO:tensorflow:global_step/sec: 34.9125
# INFO:tensorflow:probabilities = [[0.5724946  0.42750534]] (1.444 sec)
# INFO:tensorflow:loss = 0.55775195, step = 65241 (2.865 sec)
# INFO:tensorflow:probabilities = [[0.5760625  0.42393753]] (1.434 sec)
# INFO:tensorflow:Saving checkpoints for 65300 into /models/CNN2600/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.55084944.
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-65300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 65301 into /models/CNN2600/model.ckpt.
# INFO:tensorflow:probabilities = [[0.5766668  0.42333326]]
# INFO:tensorflow:loss = 0.55049074, step = 65301
# INFO:tensorflow:probabilities = [[0.58008516 0.41991487]] (1.574 sec)
# INFO:tensorflow:global_step/sec: 33.7071
# INFO:tensorflow:probabilities = [[0.57430017 0.42569983]] (1.394 sec)
# INFO:tensorflow:loss = 0.5546031, step = 65401 (2.967 sec)
# INFO:tensorflow:probabilities = [[0.56958765 0.4304123 ]] (1.446 sec)
# INFO:tensorflow:probabilities = [[0.58183604 0.41816399]] (1.405 sec)
# INFO:tensorflow:global_step/sec: 35.7526
# INFO:tensorflow:probabilities = [[0.58561665 0.41438332]] (1.391 sec)
# INFO:tensorflow:loss = 0.53508985, step = 78001 (2.796 sec)
# INFO:tensorflow:probabilities = [[0.5883636  0.41163644]] (1.380 sec)
# INFO:tensorflow:global_step/sec: 36.0746
# INFO:tensorflow:probabilities = [[0.5910403  0.40895966]] (1.392 sec)
# INFO:tensorflow:loss = 0.52587104, step = 78101 (2.773 sec)
# INFO:tensorflow:probabilities = [[0.59316593 0.40683413]] (1.385 sec)
# INFO:tensorflow:global_step/sec: 36.1134
# INFO:tensorflow:probabilities = [[0.5933398 0.4066602]] (1.383 sec)
# INFO:tensorflow:loss = 0.52198803, step = 78201 (2.768 sec)
# INFO:tensorflow:probabilities = [[0.5973144 0.4026856]] (1.401 sec)
# INFO:tensorflow:global_step/sec: 35.1084
# INFO:tensorflow:probabilities = [[0.5964141  0.40358597]] (1.448 sec)
# INFO:tensorflow:loss = 0.5168201, step = 78301 (2.848 sec)
# INFO:tensorflow:probabilities = [[0.5974627  0.40253735]] (1.492 sec)
# INFO:tensorflow:Saving checkpoints for 78360 into /models/CNN2600/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.91190755.

# %%
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.7
session = tf.Session(config=config)

ev_results = np.zeros((len(ev_label), 1))
with tf.device('/device:GPU:2'):

    # Evaluate the model and print results
    for i in range(len(ev_label)):
        eval_input_fn = tf.estimator.inputs.numpy_input_fn(
            x={"x": ev_data_sh[i:i+1]},
            y=ev_label_sh[i:i+1],
            num_epochs=1,
            shuffle=False)
        eval_results = net_classifier.evaluate(input_fn=eval_input_fn)
        
        ev_results[i] = eval_results["accuracy"]
# Out:
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:49
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:50
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:50
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:50
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:51
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:51
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:52
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:52
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:52
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:53
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:53
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:54
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:54
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:55
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:55
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:56
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:56
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:56
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:57
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:57
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:58
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:58
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:58
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:59
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:50:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:50:59
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:00
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:00
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:01
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:01
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:01
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:02
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:02
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:03
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:03
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:03
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:04
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:04
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:05
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:05
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:05
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:06
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:06
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:07
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:07
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:08
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:08
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:08
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:09
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:09
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:09
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:10
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:10
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:11
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:11
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:11
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:12
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:12
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:13
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:13
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:14
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:14
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:14
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:15
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:15
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:16
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:16
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:16
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:17
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:17
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:51:18
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:51:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# ...
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:15
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:15
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:16
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:16
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:17
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:17
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:18
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:18
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:18
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:19
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:19
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:20
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:20
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:21
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:21
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:21
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:22
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 1.0, global_step = 78360, loss = 0.5142393
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:22
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:22
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:23
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:23
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:23
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:24
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:24
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919
# INFO:tensorflow:Calling model_fn.
# (?, 480, 640, 48)
# (?, 240, 320, 48)
# (?, 240, 320, 96)
# (?, 120, 160, 96)
# (?, 120, 160, 96)
# (?, 60, 80, 96)
# (?, 60, 80, 96)
# (?, 30, 40, 96)
# (?, 30, 40, 96)
# (?, 15, 20, 96)
# (?, 28800)
# (?, 1024)
# (?, 2)
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:55:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /models/CNN2600/model.ckpt-78360
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:55:25
# INFO:tensorflow:Saving dict for global step 78360: accuracy = 0.0, global_step = 78360, loss = 0.9111919

# %%
print(np.mean(ev_results))
# Out:
# 0.5451761102603369

# %%
np.savetxt("torn_2600.csv", torn_idx, delimiter=',')
np.savetxt("untorn_2600.csv", untorn_idx, delimiter=',')


np.savetxt("shuf1_2600.csv", shuf1, delimiter=',')
np.savetxt("shuf2_2600.csv", shuf2, delimiter=',')

# %%
fail_idx = np.where(ev_results == 0)
print(fail_idx[0])
print(len(fail_idx[0]))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

temp_img = ev_data_sh[501][:].reshape([480, 640, 3])
#temp_img = tf.reshape(ev_data_sh[33][:], [480, 640, 3])

temp_img = 255-temp_img

width = 12
height = 12
plt.figure(figsize=(width, height))
plt.axis("off")
plt.imshow(cv2.cvtColor(temp_img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for i in range(len(fail_idx[0])):

    temp_img = ev_data_sh[fail_idx[0][i]][:].reshape([480, 640, 3])

    temp_img = 255-temp_img

    width = 12
    height = 12
    plt.figure(figsize=(width, height))
    plt.axis("off")
    plt.imshow(cv2.cvtColor(temp_img, cv2.COLOR_BGR2RGB))
    plt.show()

# %% [markdown]
# ## Results
# 훈련 데이터셋 2612개
# 검증 데이터셋 653개
#
# 정확도 87.7%
#
# CNN layer 5개
# Training step: 40000회
# Batch size: 1

# %% [markdown]
# ## 오현석 교수님
# 오교수님 데이터셋으로 훈련시킨 CNN으로 우리 데이터셋 테스트 -> 44% 정확도
# 우리 데이터셋으로 훈련시킨 CNN으로 오교수님 데이터셋 테스트 -> 60% 정확도
#
# LeNet 사용
# 이미지 크기 64 x 64
