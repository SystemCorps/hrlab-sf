# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf

import cv2
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
import random

import json
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# GPU selection (memory)
import os
#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
#os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
# Data info.

width = 640
height = 480
channel = 3


# resize
r_w = 512
r_h = 512

total_pix = r_w * r_h * channel

# %%
def data_process(d_dir, split_rate):
    
    num_class = len(d_dir.keys())

    out = {}
    

    for i in range(num_class):
        x_train, x_test = train_test_split(d_dir[i], test_size=split_rate)
        
        if i == 0:
            train_temp = x_train
            test_temp = x_test
        else:
            train_temp.extend(x_train)
            test_temp.extend(x_test)
    
    random.shuffle(train_temp)
    out['train'] = train_temp
    random.shuffle(test_temp)
    out['test'] = test_temp
    
    return out

# %%
image_dir1 = '/dataset_full/'
class_name1 = ['Untorn', 'Torn']

data_dir1 = {}
for i in range(len(class_name1)):
    temp_dir = image_dir1 + class_name1[i]
    img_files = [[os.path.join(temp_dir, f), np.int16(i)] for f in os.listdir(temp_dir) if f.endswith('.png')]
    data_dir1[i] = img_files
print(len(data_dir1[0]), len(data_dir1[1]))
# Out:
# 2136 2427

# %%
tr_data_dir = data_process(data_dir1, 0.2)

# %%
data_txt = open('./data_split/data_dir_dict_0614.txt', 'r')
data_json = data_txt.read()
tr_data_dir = json.loads(data_json)

# %%
def default(o):
    if isinstance(o, (np.int_, np.intc, np.intp, np.int8,
                      np.int16, np.int32, np.int64, np.uint8,
                      np.uint16,np.uint32, np.uint64)):
        return int(o)

    raise TypeError

with open('./data_split/data_dir_dict_0614.txt', 'w') as file:
    file.write(json.dumps(tr_data_dir, default=default))

# %%
test = open('./data_split/data_dir_dict_0614.txt', 'r')
data = test.read()
data2 = json.loads(data)

# %%
print(data2)
# Out:
# {'test': [['/dataset_full/Torn/Torn (1058).png', 1], ['/dataset_full/Torn/Torn (1297).png', 1], ['/dataset_full/Untorn/Untorn (1988).png', 0], ['/dataset_full/Untorn/Untorn (780).png', 0], ['/dataset_full/Untorn/Untorn (57).png', 0], ['/dataset_full/Torn/Torn (1881).png', 1], ['/dataset_full/Torn/Torn (769).png', 1], ['/dataset_full/Torn/Torn (1040).png', 1], ['/dataset_full/Untorn/Untorn (2090).png', 0], ['/dataset_full/Torn/Torn (626).png', 1], ['/dataset_full/Torn/Torn (2234).png', 1], ['/dataset_full/Untorn/Untorn (668).png', 0], ['/dataset_full/Torn/Torn (2420).png', 1], ['/dataset_full/Torn/Torn (1533).png', 1], ['/dataset_full/Torn/Torn (2018).png', 1], ['/dataset_full/Untorn/Untorn (1928).png', 0], ['/dataset_full/Torn/Torn (365).png', 1], ['/dataset_full/Torn/Torn (828).png', 1], ['/dataset_full/Torn/Torn (1621).png', 1], ['/dataset_full/Torn/Torn (1319).png', 1], ['/dataset_full/Untorn/Untorn (348).png', 0], ['/dataset_full/Torn/Torn (1082).png', 1], ['/dataset_full/Untorn/Untorn (407).png', 0], ['/dataset_full/Untorn/Untorn (399).png', 0], ['/dataset_full/Untorn/Untorn (903).png', 0], ['/dataset_full/Untorn/Untorn (262).png', 0], ['/dataset_full/Torn/Torn (2037).png', 1], ['/dataset_full/Torn/Torn (2274).png', 1], ['/dataset_full/Untorn/Untorn (1735).png', 0], ['/dataset_full/Torn/Torn (2262).png', 1], ['/dataset_full/Torn/Torn (1776).png', 1], ['/dataset_full/Untorn/Untorn (1944).png', 0], ['/dataset_full/Untorn/Untorn (1012).png', 0], ['/dataset_full/Torn/Torn (439).png', 1], ['/dataset_full/Torn/Torn (1834).png', 1], ['/dataset_full/Untorn/Untorn (506).png', 0], ['/dataset_full/Torn/Torn (1667).png', 1], ['/dataset_full/Torn/Torn (625).png', 1], ['/dataset_full/Untorn/Untorn (2074).png', 0], ['/dataset_full/Torn/Torn (1084).png', 1], ['/dataset_full/Torn/Torn (1289).png', 1], ['/dataset_full/Untorn/Untorn (109).png', 0], ['/dataset_full/Torn/Torn (54).png', 1], ['/dataset_full/Torn/Torn (112).png', 1], ['/dataset_full/Untorn/Untorn (1067).png', 0], ['/dataset_full/Untorn/Untorn (1537).png', 0], ['/dataset_full/Torn/Torn (1118).png', 1], ['/dataset_full/Torn/Torn (1535).png', 1], ['/dataset_full/Torn/Torn (2263).png', 1], ['/dataset_full/Torn/Torn (655).png', 1], ['/dataset_full/Torn/Torn (293).png', 1], ['/dataset_full/Untorn/Untorn (1062).png', 0], ['/dataset_full/Untorn/Untorn (701).png', 0], ['/dataset_full/Torn/Torn (1563).png', 1], ['/dataset_full/Untorn/Untorn (500).png', 0], ['/dataset_full/Untorn/Untorn (1512).png', 0], ['/dataset_full/Untorn/Untorn (1359).png', 0], ['/dataset_full/Untorn/Untorn (182).png', 0], ['/dataset_full/Untorn/Untorn (1968).png', 0], ['/dataset_full/Torn/Torn (1400).png', 1], ['/dataset_full/Untorn/Untorn (1335).png', 0], ['/dataset_full/Untorn/Untorn (472).png', 0], ['/dataset_full/Torn/Torn (250).png', 1], ['/dataset_full/Untorn/Untorn (1952).png', 0], ['/dataset_full/Torn/Torn (2246).png', 1], ['/dataset_full/Torn/Torn (732).png', 1], ['/dataset_full/Untorn/Untorn (1014).png', 0], ['/dataset_full/Torn/Torn (226).png', 1], ['/dataset_full/Torn/Torn (95).png', 1], ['/dataset_full/Torn/Torn (2032).png', 1], ['/dataset_full/Torn/Torn (21).png', 1], ['/dataset_full/Untorn/Untorn (1462).png', 0], ['/dataset_full/Untorn/Untorn (1603).png', 0], ['/dataset_full/Torn/Torn (2331).png', 1], ['/dataset_full/Torn/Torn (1547).png', 1], ['/dataset_full/Torn/Torn (955).png', 1], ['/dataset_full/Torn/Torn (1039).png', 1], ['/dataset_full/Torn/Torn (1152).png', 1], ['/dataset_full/Torn/Torn (604).png', 1], ['/dataset_full/Untorn/Untorn (762).png', 0], ['/dataset_full/Untorn/Untorn (1243).png', 0], ['/dataset_full/Torn/Torn (278).png', 1], ['/dataset_full/Torn/Torn (2273).png', 1], ['/dataset_full/Torn/Torn (1459).png', 1], ['/dataset_full/Torn/Torn (38).png', 1], ['/dataset_full/Torn/Torn (1483).png', 1], ['/dataset_full/Untorn/Untorn (1836).png', 0], ['/dataset_full/Torn/Torn (257).png', 1], ['/dataset_full/Untorn/Untorn (1901).png', 0], ['/dataset_full/Untorn/Untorn (531).png', 0], ['/dataset_fu ...

# %%
print(data2['test'])
# Out:
# [['/dataset_full/Torn/Torn (1058).png', 1], ['/dataset_full/Torn/Torn (1297).png', 1], ['/dataset_full/Untorn/Untorn (1988).png', 0], ['/dataset_full/Untorn/Untorn (780).png', 0], ['/dataset_full/Untorn/Untorn (57).png', 0], ['/dataset_full/Torn/Torn (1881).png', 1], ['/dataset_full/Torn/Torn (769).png', 1], ['/dataset_full/Torn/Torn (1040).png', 1], ['/dataset_full/Untorn/Untorn (2090).png', 0], ['/dataset_full/Torn/Torn (626).png', 1], ['/dataset_full/Torn/Torn (2234).png', 1], ['/dataset_full/Untorn/Untorn (668).png', 0], ['/dataset_full/Torn/Torn (2420).png', 1], ['/dataset_full/Torn/Torn (1533).png', 1], ['/dataset_full/Torn/Torn (2018).png', 1], ['/dataset_full/Untorn/Untorn (1928).png', 0], ['/dataset_full/Torn/Torn (365).png', 1], ['/dataset_full/Torn/Torn (828).png', 1], ['/dataset_full/Torn/Torn (1621).png', 1], ['/dataset_full/Torn/Torn (1319).png', 1], ['/dataset_full/Untorn/Untorn (348).png', 0], ['/dataset_full/Torn/Torn (1082).png', 1], ['/dataset_full/Untorn/Untorn (407).png', 0], ['/dataset_full/Untorn/Untorn (399).png', 0], ['/dataset_full/Untorn/Untorn (903).png', 0], ['/dataset_full/Untorn/Untorn (262).png', 0], ['/dataset_full/Torn/Torn (2037).png', 1], ['/dataset_full/Torn/Torn (2274).png', 1], ['/dataset_full/Untorn/Untorn (1735).png', 0], ['/dataset_full/Torn/Torn (2262).png', 1], ['/dataset_full/Torn/Torn (1776).png', 1], ['/dataset_full/Untorn/Untorn (1944).png', 0], ['/dataset_full/Untorn/Untorn (1012).png', 0], ['/dataset_full/Torn/Torn (439).png', 1], ['/dataset_full/Torn/Torn (1834).png', 1], ['/dataset_full/Untorn/Untorn (506).png', 0], ['/dataset_full/Torn/Torn (1667).png', 1], ['/dataset_full/Torn/Torn (625).png', 1], ['/dataset_full/Untorn/Untorn (2074).png', 0], ['/dataset_full/Torn/Torn (1084).png', 1], ['/dataset_full/Torn/Torn (1289).png', 1], ['/dataset_full/Untorn/Untorn (109).png', 0], ['/dataset_full/Torn/Torn (54).png', 1], ['/dataset_full/Torn/Torn (112).png', 1], ['/dataset_full/Untorn/Untorn (1067).png', 0], ['/dataset_full/Untorn/Untorn (1537).png', 0], ['/dataset_full/Torn/Torn (1118).png', 1], ['/dataset_full/Torn/Torn (1535).png', 1], ['/dataset_full/Torn/Torn (2263).png', 1], ['/dataset_full/Torn/Torn (655).png', 1], ['/dataset_full/Torn/Torn (293).png', 1], ['/dataset_full/Untorn/Untorn (1062).png', 0], ['/dataset_full/Untorn/Untorn (701).png', 0], ['/dataset_full/Torn/Torn (1563).png', 1], ['/dataset_full/Untorn/Untorn (500).png', 0], ['/dataset_full/Untorn/Untorn (1512).png', 0], ['/dataset_full/Untorn/Untorn (1359).png', 0], ['/dataset_full/Untorn/Untorn (182).png', 0], ['/dataset_full/Untorn/Untorn (1968).png', 0], ['/dataset_full/Torn/Torn (1400).png', 1], ['/dataset_full/Untorn/Untorn (1335).png', 0], ['/dataset_full/Untorn/Untorn (472).png', 0], ['/dataset_full/Torn/Torn (250).png', 1], ['/dataset_full/Untorn/Untorn (1952).png', 0], ['/dataset_full/Torn/Torn (2246).png', 1], ['/dataset_full/Torn/Torn (732).png', 1], ['/dataset_full/Untorn/Untorn (1014).png', 0], ['/dataset_full/Torn/Torn (226).png', 1], ['/dataset_full/Torn/Torn (95).png', 1], ['/dataset_full/Torn/Torn (2032).png', 1], ['/dataset_full/Torn/Torn (21).png', 1], ['/dataset_full/Untorn/Untorn (1462).png', 0], ['/dataset_full/Untorn/Untorn (1603).png', 0], ['/dataset_full/Torn/Torn (2331).png', 1], ['/dataset_full/Torn/Torn (1547).png', 1], ['/dataset_full/Torn/Torn (955).png', 1], ['/dataset_full/Torn/Torn (1039).png', 1], ['/dataset_full/Torn/Torn (1152).png', 1], ['/dataset_full/Torn/Torn (604).png', 1], ['/dataset_full/Untorn/Untorn (762).png', 0], ['/dataset_full/Untorn/Untorn (1243).png', 0], ['/dataset_full/Torn/Torn (278).png', 1], ['/dataset_full/Torn/Torn (2273).png', 1], ['/dataset_full/Torn/Torn (1459).png', 1], ['/dataset_full/Torn/Torn (38).png', 1], ['/dataset_full/Torn/Torn (1483).png', 1], ['/dataset_full/Untorn/Untorn (1836).png', 0], ['/dataset_full/Torn/Torn (257).png', 1], ['/dataset_full/Untorn/Untorn (1901).png', 0], ['/dataset_full/Untorn/Untorn (531).png', 0], ['/dataset_full/Untorn ...
