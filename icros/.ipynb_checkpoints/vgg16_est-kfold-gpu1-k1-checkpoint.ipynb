# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib.layers.python.layers import layers as layers_lib
from tensorflow.python.ops import array_ops

import cv2
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
import random

import json

tf.logging.set_verbosity(tf.logging.INFO)

# GPU selection (memory)
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data_txt = open('./data_split/5fold_0802.txt', 'r')
data_json = data_txt.read()
tr_data_dir = json.loads(data_json)

# %%
# Data info.

width = 640
height = 480
channel = 3


# resize
r_w = 224
r_h = 224

total_pix = r_w * r_h * channel

# %%
tr_data_dir['train0'][0]
# Out:
# '/dataset_full/Torn/Torn (1220).png'

# %%
def vgg16(features, labels, mode):
    
    """Model function for CNN."""
    # Input Layer
    # Reshape X to 4-D tensor: [batch_size, height, width, channels]
    # Our Fishing net image size is 640x480 and 3-channel (RGB)
    input_layer = tf.reshape(features["x"], [-1, 224, 224, 3])
    dropout_keep_prob = 0.5
    num_classes = 2
    is_training = True
    
    
    net = layers_lib.repeat(
        input_layer, 2, layers.conv2d, 64, [3, 3], scope='conv1')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool1')
    net = layers_lib.repeat(net, 2, layers.conv2d, 128, [3, 3], scope='conv2')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool2')
    net = layers_lib.repeat(net, 3, layers.conv2d, 256, [3, 3], scope='conv3')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool3')
    net = layers_lib.repeat(net, 3, layers.conv2d, 512, [3, 3], scope='conv4')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool4')
    net = layers_lib.repeat(net, 3, layers.conv2d, 512, [3, 3], scope='conv5')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool5')
    # Use conv2d instead of fully_connected layers.
    net = layers.conv2d(net, 4096, [7, 7], padding='VALID', scope='fc6')
    net = layers_lib.dropout(
        net, dropout_keep_prob, is_training=is_training, scope='dropout6')
    net = layers.conv2d(net, 4096, [1, 1], scope='fc7')
    net = layers_lib.dropout(
        net, dropout_keep_prob, is_training=is_training, scope='dropout7')
    net = layers.conv2d(
        net,
        num_classes, [1, 1],
        activation_fn=None,
        normalizer_fn=None,
        scope='fc8')
    net = array_ops.squeeze(net, [1, 2], name='fc8/squeezed')
    
    logits = net
    


    predictions = {
        # Generate predictions (for PREDICT and EVAL mode)
        "classes": tf.argmax(input=logits, axis=1),
        # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
        # `logging_hook`.
        "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
    }
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Calculate Loss (for both TRAIN and EVAL modes)
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
    acc = tf.metrics.accuracy(labels=labels, predictions=predictions["classes"])

    tf.summary.scalar('train_acc', acc[1])
    # sparse_softmax_cross_entropy cannot use one-hot encoding

    #loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=labels, logits=logits)

    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        #optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
        optimizer = tf.train.AdamOptimizer(learning_rate=0.0001)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {
        "accuracy": tf.metrics.accuracy(
            labels=labels, predictions=predictions["classes"])}
    return tf.estimator.EstimatorSpec(
        mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
#config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = 0.9
#session = tf.Session(config=config)

k = 1
total_res = {}
add_dir = '/hdd3/dhj_container/DB'


val_result = []

f_dir = "/hdd3/dhj_container/ICROS_vgg/kfold0811_%d/" % k

if not tf.gfile.Exists(f_dir):
    tf.gfile.MakeDirs(f_dir)

net_classifier = tf.estimator.Estimator(
    model_fn=vgg16, model_dir=f_dir)

# Set up logging for predictions
# Log the values in the "Softmax" tensor with label "probabilities"
tensors_to_log = {"probabilities": "softmax_tensor"}
logging_hook = tf.train.LoggingTensorHook(
    tensors=tensors_to_log, every_n_iter=50)



tr_data = np.zeros((len(tr_data_dir['train%d'%k]), total_pix), dtype=np.float32)
tr_label = np.zeros((len(tr_data_dir['train%d'%k]), 1), dtype=np.int32)

for j in range(len(tr_data)):
    img = cv2.imread(add_dir+tr_data_dir['train%d'%k][j])
    img2 = cv2.resize(img, (r_w, r_h), interpolation=cv2.INTER_CUBIC)
    tr_data[j,:] = img2.flatten()

    if 'Untorn' in tr_data_dir['train%d'%k][j]:
        tr_label[j] = 0
    elif 'normal' in tr_data_dir['train%d'%k][j]:
        tr_label[j] = 0

    else:
        tr_label[j] = 1


val_data = np.zeros((len(tr_data_dir['valid%d'%k]), total_pix), dtype=np.float32)
val_label = np.zeros((len(tr_data_dir['valid%d'%k]), 1), dtype=np.int32)

for j in range(len(val_data)):
    img = cv2.imread(add_dir+tr_data_dir['valid%d'%k][j])
    img2 = cv2.resize(img, (r_w, r_h), interpolation=cv2.INTER_CUBIC)
    val_data[j,:] = img2.flatten()

    if 'Untorn' in tr_data_dir['valid%d'%k][j]:
        val_label[j] = 0
    elif 'normal' in tr_data_dir['valid%d'%k][j]:
        val_label[j] = 0

    else:
        val_label[j] = 1




batch_s = 32
epochs = 30
tr_steps = int(tr_data.shape[0]/batch_s*epochs)
step_in_epoch = int(tr_data.shape[0]/batch_s)+1
in_steps = 1



train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": tr_data},
    y=tr_label,
    batch_size=batch_s,
    num_epochs=epochs,
    shuffle=False)

eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": val_data},
    y=val_label,
    batch_size=64,
    num_epochs=1,
    shuffle=False)

train_spec = tf.estimator.TrainSpec(input_fn=train_input_fn, max_steps=tr_steps)
eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_fn, steps=None, throttle_secs=100)

tf.estimator.train_and_evaluate(net_classifier, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_log_step_count_steps': 100, '_task_id': 0, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fdeb80b2208>, '_model_dir': '/hdd3/dhj_container/ICROS_vgg/kfold0811_1/', '_is_chief': True, '_session_config': None, '_evaluation_master': '', '_save_checkpoints_steps': None, '_num_worker_replicas': 1, '_master': '', '_save_checkpoints_secs': 600, '_task_type': 'worker', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_keep_checkpoint_max': 5}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 100 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 1, loss = 0.75490505
# INFO:tensorflow:global_step/sec: 3.07034
# INFO:tensorflow:step = 101, loss = 0.53139925 (32.571 sec)
# INFO:tensorflow:global_step/sec: 3.06187
# INFO:tensorflow:step = 201, loss = 0.47782618 (32.660 sec)
# INFO:tensorflow:Saving checkpoints for 257 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.44071993.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:13:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-257
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:13:14
# INFO:tensorflow:Saving dict for global step 257: accuracy = 0.7423246, global_step = 257, loss = 0.5195452
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-257
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 258 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 258, loss = 0.5319343
# INFO:tensorflow:global_step/sec: 3.04904
# INFO:tensorflow:step = 358, loss = 0.30914503 (32.798 sec)
# INFO:tensorflow:global_step/sec: 3.01809
# INFO:tensorflow:step = 458, loss = 0.32262474 (33.133 sec)
# INFO:tensorflow:Saving checkpoints for 523 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.24147405.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:15:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-523
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:15:09
# INFO:tensorflow:Saving dict for global step 523: accuracy = 0.8760965, global_step = 523, loss = 0.2954727
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-523
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 524 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 524, loss = 0.37942117
# INFO:tensorflow:global_step/sec: 3.04746
# INFO:tensorflow:step = 624, loss = 0.2012667 (32.816 sec)
# INFO:tensorflow:global_step/sec: 2.99404
# INFO:tensorflow:step = 724, loss = 0.2524712 (33.399 sec)
# INFO:tensorflow:Saving checkpoints for 790 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.15788226.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:17:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-790
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:17:04
# INFO:tensorflow:Saving dict for global step 790: accuracy = 0.9375, global_step = 790, loss = 0.15926513
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-790
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 791 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 791, loss = 0.16607824
# INFO:tensorflow:global_step/sec: 3.04124
# INFO:tensorflow:step = 891, loss = 0.1990107 (32.883 sec)
# INFO:tensorflow:global_step/sec: 3.01258
# INFO:tensorflow:step = 991, loss = 0.13903545 (33.194 sec)
# INFO:tensorflow:Saving checkpoints for 1058 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.011004893.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:18:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1058
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:18:59
# INFO:tensorflow:Saving dict for global step 1058: accuracy = 0.9714912, global_step = 1058, loss = 0.07999914
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1058
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1059 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 1059, loss = 0.052153893
# INFO:tensorflow:global_step/sec: 3.03241
# INFO:tensorflow:step = 1159, loss = 0.034349985 (32.979 sec)
# INFO:tensorflow:global_step/sec: 3.01265
# INFO:tensorflow:step = 1259, loss = 0.055448413 (33.193 sec)
# INFO:tensorflow:Saving checkpoints for 1324 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.028314538.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:20:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1324
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:20:54
# INFO:tensorflow:Saving dict for global step 1324: accuracy = 0.96820176, global_step = 1324, loss = 0.099642776
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1324
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1325 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 1325, loss = 0.046246897
# INFO:tensorflow:global_step/sec: 3.04941
# INFO:tensorflow:step = 1425, loss = 0.04975784 (32.795 sec)
# INFO:tensorflow:global_step/sec: 3.01279
# INFO:tensorflow:step = 1525, loss = 0.040956154 (33.191 sec)
# INFO:tensorflow:Saving checkpoints for 1592 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0039296695.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:22:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1592
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:22:49
# INFO:tensorflow:Saving dict for global step 1592: accuracy = 0.9791667, global_step = 1592, loss = 0.073839255
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1592
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1593 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 1593, loss = 0.01739955
# INFO:tensorflow:global_step/sec: 3.03246
# INFO:tensorflow:step = 1693, loss = 0.00597332 (32.979 sec)
# INFO:tensorflow:global_step/sec: 3.01144
# INFO:tensorflow:step = 1793, loss = 0.009542616 (33.207 sec)
# INFO:tensorflow:Saving checkpoints for 1858 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0007787075.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:24:40
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1858
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:24:44
# INFO:tensorflow:Saving dict for global step 1858: accuracy = 0.98355263, global_step = 1858, loss = 0.047721006
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-1858
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1859 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 1859, loss = 0.00501085
# INFO:tensorflow:global_step/sec: 3.03394
# INFO:tensorflow:step = 1959, loss = 6.325074e-05 (32.962 sec)
# INFO:tensorflow:global_step/sec: 3.0023
# INFO:tensorflow:step = 2059, loss = 0.0031827723 (33.308 sec)
# INFO:tensorflow:Saving checkpoints for 2124 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 6.35097e-05.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:26:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2124
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:26:38
# INFO:tensorflow:Saving dict for global step 2124: accuracy = 0.98903507, global_step = 2124, loss = 0.036751628
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2124
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2125 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 2125, loss = 0.001042987
# INFO:tensorflow:global_step/sec: 3.04542
# INFO:tensorflow:step = 2225, loss = 0.000409235 (32.838 sec)
# INFO:tensorflow:global_step/sec: 3.02094
# INFO:tensorflow:step = 2325, loss = 0.00028768368 (33.103 sec)
# INFO:tensorflow:Saving checkpoints for 2391 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.015671821.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:28:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2391
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:28:33
# INFO:tensorflow:Saving dict for global step 2391: accuracy = 0.9879386, global_step = 2391, loss = 0.04902693
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2391
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2392 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 2392, loss = 0.00052163325
# INFO:tensorflow:global_step/sec: 3.02287
# INFO:tensorflow:step = 2492, loss = 0.00075877697 (33.083 sec)
# INFO:tensorflow:global_step/sec: 2.99802
# INFO:tensorflow:step = 2592, loss = 0.0014545427 (33.356 sec)
# INFO:tensorflow:Saving checkpoints for 2657 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.019477643.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:30:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2657
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:30:28
# INFO:tensorflow:Saving dict for global step 2657: accuracy = 0.9660088, global_step = 2657, loss = 0.10108719
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2657
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2658 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 2658, loss = 0.0073276423
# INFO:tensorflow:global_step/sec: 3.02052
# INFO:tensorflow:step = 2758, loss = 0.04138629 (33.109 sec)
# INFO:tensorflow:global_step/sec: 3.0157
# INFO:tensorflow:step = 2858, loss = 0.16731276 (33.159 sec)
# INFO:tensorflow:Saving checkpoints for 2923 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0018931008.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:32:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2923
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:32:24
# INFO:tensorflow:Saving dict for global step 2923: accuracy = 0.9846491, global_step = 2923, loss = 0.03609437
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-2923
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2924 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 2924, loss = 0.0038503255
# INFO:tensorflow:global_step/sec: 3.03375
# INFO:tensorflow:step = 3024, loss = 0.0009588998 (32.964 sec)
# INFO:tensorflow:global_step/sec: 3.01729
# INFO:tensorflow:step = 3124, loss = 0.019360173 (33.143 sec)
# INFO:tensorflow:Saving checkpoints for 3188 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0052297194.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:34:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-3188
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:34:20
# INFO:tensorflow:Saving dict for global step 3188: accuracy = 0.9868421, global_step = 3188, loss = 0.03497745
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-3188
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3189 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:step = 3189, loss = 0.0042941356
# INFO:tensorflow:global_step/sec: 3.04253
# INFO:tensorflow:step = 3289, loss = 5.347885e-05 (32.869 sec)
# INFO:tensorflow:global_step/sec: 3.00334
# INFO:tensorflow:step = 3389, loss = 0.00027509505 (33.296 sec)
# INFO:tensorflow:Saving checkpoints for 3422 into /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.6060214e-06.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-06:36:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_1/model.ckpt-3422
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-06:36:04
# INFO:tensorflow:Saving dict for global step 3422: accuracy = 0.98355263, global_step = 3422, loss = 0.060975537
