# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import tensorflow as tf
from tensorflow.contrib import layers
from tensorflow.contrib.layers.python.layers import layers as layers_lib
from tensorflow.python.ops import array_ops

import cv2
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
import random

import json

tf.logging.set_verbosity(tf.logging.INFO)

# GPU selection (memory)
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="0"
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
data_txt = open('./data_split/5fold_0802.txt', 'r')
data_json = data_txt.read()
tr_data_dir = json.loads(data_json)

# %%
# Data info.

width = 640
height = 480
channel = 3


# resize
r_w = 224
r_h = 224

total_pix = r_w * r_h * channel

# %%
tr_data_dir['train0'][0]
# Out:
# '/dataset_full/Torn/Torn (1220).png'

# %%
def vgg16(features, labels, mode):
    
    """Model function for CNN."""
    # Input Layer
    # Reshape X to 4-D tensor: [batch_size, height, width, channels]
    # Our Fishing net image size is 640x480 and 3-channel (RGB)
    input_layer = tf.reshape(features["x"], [-1, 224, 224, 3])
    dropout_keep_prob = 0.5
    num_classes = 2
    is_training = True
    
    
    net = layers_lib.repeat(
        input_layer, 2, layers.conv2d, 64, [3, 3], scope='conv1')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool1')
    net = layers_lib.repeat(net, 2, layers.conv2d, 128, [3, 3], scope='conv2')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool2')
    net = layers_lib.repeat(net, 3, layers.conv2d, 256, [3, 3], scope='conv3')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool3')
    net = layers_lib.repeat(net, 3, layers.conv2d, 512, [3, 3], scope='conv4')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool4')
    net = layers_lib.repeat(net, 3, layers.conv2d, 512, [3, 3], scope='conv5')
    net = layers_lib.max_pool2d(net, [2, 2], scope='pool5')
    # Use conv2d instead of fully_connected layers.
    net = layers.conv2d(net, 4096, [7, 7], padding='VALID', scope='fc6')
    net = layers_lib.dropout(
        net, dropout_keep_prob, is_training=is_training, scope='dropout6')
    net = layers.conv2d(net, 4096, [1, 1], scope='fc7')
    net = layers_lib.dropout(
        net, dropout_keep_prob, is_training=is_training, scope='dropout7')
    net = layers.conv2d(
        net,
        num_classes, [1, 1],
        activation_fn=None,
        normalizer_fn=None,
        scope='fc8')
    net = array_ops.squeeze(net, [1, 2], name='fc8/squeezed')
    
    logits = net
    


    predictions = {
        # Generate predictions (for PREDICT and EVAL mode)
        "classes": tf.argmax(input=logits, axis=1),
        # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
        # `logging_hook`.
        "probabilities": tf.nn.softmax(logits, name="softmax_tensor")
    }
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)

    # Calculate Loss (for both TRAIN and EVAL modes)
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
    acc = tf.metrics.accuracy(labels=labels, predictions=predictions["classes"])

    tf.summary.scalar('train_acc', acc[1])
    # sparse_softmax_cross_entropy cannot use one-hot encoding

    #loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=labels, logits=logits)

    # Configure the Training Op (for TRAIN mode)
    if mode == tf.estimator.ModeKeys.TRAIN:
        #optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
        optimizer = tf.train.AdamOptimizer(learning_rate=0.0001)
        train_op = optimizer.minimize(
            loss=loss,
            global_step=tf.train.get_global_step())
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)

    # Add evaluation metrics (for EVAL mode)
    eval_metric_ops = {
        "accuracy": tf.metrics.accuracy(
            labels=labels, predictions=predictions["classes"])}
    return tf.estimator.EstimatorSpec(
        mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
#config = tf.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = 0.9
#session = tf.Session(config=config)

k = 3
total_res = {}
add_dir = '/hdd3/dhj_container/DB'


val_result = []

f_dir = "/hdd3/dhj_container/ICROS_vgg/kfold0811_%d/" % k

if not tf.gfile.Exists(f_dir):
    tf.gfile.MakeDirs(f_dir)

net_classifier = tf.estimator.Estimator(
    model_fn=vgg16, model_dir=f_dir)

# Set up logging for predictions
# Log the values in the "Softmax" tensor with label "probabilities"
tensors_to_log = {"probabilities": "softmax_tensor"}
logging_hook = tf.train.LoggingTensorHook(
    tensors=tensors_to_log, every_n_iter=50)



tr_data = np.zeros((len(tr_data_dir['train%d'%k]), total_pix), dtype=np.float32)
tr_label = np.zeros((len(tr_data_dir['train%d'%k]), 1), dtype=np.int32)

for j in range(len(tr_data)):
    img = cv2.imread(add_dir+tr_data_dir['train%d'%k][j])
    img2 = cv2.resize(img, (r_w, r_h), interpolation=cv2.INTER_CUBIC)
    tr_data[j,:] = img2.flatten()

    if 'Untorn' in tr_data_dir['train%d'%k][j]:
        tr_label[j] = 0
    elif 'normal' in tr_data_dir['train%d'%k][j]:
        tr_label[j] = 0

    else:
        tr_label[j] = 1


val_data = np.zeros((len(tr_data_dir['valid%d'%k]), total_pix), dtype=np.float32)
val_label = np.zeros((len(tr_data_dir['valid%d'%k]), 1), dtype=np.int32)

for j in range(len(val_data)):
    img = cv2.imread(add_dir+tr_data_dir['valid%d'%k][j])
    img2 = cv2.resize(img, (r_w, r_h), interpolation=cv2.INTER_CUBIC)
    val_data[j,:] = img2.flatten()

    if 'Untorn' in tr_data_dir['valid%d'%k][j]:
        val_label[j] = 0
    elif 'normal' in tr_data_dir['valid%d'%k][j]:
        val_label[j] = 0

    else:
        val_label[j] = 1




batch_s = 32
epochs = 30
tr_steps = int(tr_data.shape[0]/batch_s*epochs)
step_in_epoch = int(tr_data.shape[0]/batch_s)+1
in_steps = 1



train_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": tr_data},
    y=tr_label,
    batch_size=batch_s,
    num_epochs=epochs,
    shuffle=False)

eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    x={"x": val_data},
    y=val_label,
    batch_size=64,
    num_epochs=1,
    shuffle=False)

train_spec = tf.estimator.TrainSpec(input_fn=train_input_fn, max_steps=tr_steps)
eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_fn, steps=None, throttle_secs=100)

tf.estimator.train_and_evaluate(net_classifier, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_master': '', '_save_checkpoints_secs': 600, '_service': None, '_task_type': 'worker', '_global_id_in_cluster': 0, '_is_chief': True, '_tf_random_seed': None, '_log_step_count_steps': 100, '_session_config': None, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7faf2701a208>, '_task_id': 0, '_num_ps_replicas': 0, '_save_summary_steps': 100, '_model_dir': '/hdd3/dhj_container/ICROS_vgg/kfold0811_3/', '_keep_checkpoint_max': 5, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 100 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.65467614, step = 1
# INFO:tensorflow:global_step/sec: 3.05762
# INFO:tensorflow:loss = 0.47536096, step = 101 (32.708 sec)
# INFO:tensorflow:global_step/sec: 3.0509
# INFO:tensorflow:loss = 0.38715038, step = 201 (32.776 sec)
# INFO:tensorflow:Saving checkpoints for 257 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.41840562.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:09:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-257
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:09:34
# INFO:tensorflow:Saving dict for global step 257: accuracy = 0.81578946, global_step = 257, loss = 0.40053168
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-257
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 258 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.36500323, step = 258
# INFO:tensorflow:global_step/sec: 3.03768
# INFO:tensorflow:loss = 0.24127433, step = 358 (32.922 sec)
# INFO:tensorflow:global_step/sec: 2.98888
# INFO:tensorflow:loss = 0.2629958, step = 458 (33.457 sec)
# INFO:tensorflow:Saving checkpoints for 523 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.2588147.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:11:26
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-523
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:11:30
# INFO:tensorflow:Saving dict for global step 523: accuracy = 0.90460527, global_step = 523, loss = 0.2657107
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-523
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 524 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.30554336, step = 524
# INFO:tensorflow:global_step/sec: 3.04505
# INFO:tensorflow:loss = 0.194835, step = 624 (32.842 sec)
# INFO:tensorflow:global_step/sec: 2.99878
# INFO:tensorflow:loss = 0.18730256, step = 724 (33.346 sec)
# INFO:tensorflow:Saving checkpoints for 746 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.174615.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:13:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-746
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:13:32
# INFO:tensorflow:Saving dict for global step 746: accuracy = 0.89144737, global_step = 746, loss = 0.2594469
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-746
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 747 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.21692209, step = 747
# INFO:tensorflow:Loss for final step: 0.21692209.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:15:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-747
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:15:24
# INFO:tensorflow:Saving dict for global step 747: accuracy = 0.89254385, global_step = 747, loss = 0.24812602
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-747
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 748 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.19489008, step = 748
# INFO:tensorflow:global_step/sec: 3.15615
# INFO:tensorflow:loss = 0.22857916, step = 848 (31.686 sec)
# INFO:tensorflow:Saving checkpoints for 864 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.22695643.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:17:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-864
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:17:33
# INFO:tensorflow:Saving dict for global step 864: accuracy = 0.9035088, global_step = 864, loss = 0.24645525
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-864
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 865 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.2043128, step = 865
# INFO:tensorflow:global_step/sec: 3.1421
# INFO:tensorflow:loss = 0.15227924, step = 965 (31.827 sec)
# INFO:tensorflow:Saving checkpoints for 996 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.34862778.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:19:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-996
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:19:55
# INFO:tensorflow:Saving dict for global step 996: accuracy = 0.91337717, global_step = 996, loss = 0.22109397
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-996
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 997 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.14953977, step = 997
# INFO:tensorflow:global_step/sec: 3.14462
# INFO:tensorflow:loss = 0.13760382, step = 1097 (31.802 sec)
# INFO:tensorflow:Saving checkpoints for 1123 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.11594758.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:21:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1123
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:21:51
# INFO:tensorflow:Saving dict for global step 1123: accuracy = 0.9232456, global_step = 1123, loss = 0.20860635
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1123
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1124 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.120133795, step = 1124
# INFO:tensorflow:global_step/sec: 3.14375
# INFO:tensorflow:loss = 0.0930524, step = 1224 (31.811 sec)
# INFO:tensorflow:Saving checkpoints for 1228 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16451094.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:23:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1228
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:24:03
# INFO:tensorflow:Saving dict for global step 1228: accuracy = 0.94736844, global_step = 1228, loss = 0.18726464
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1228
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1229 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.07149863, step = 1229
# INFO:tensorflow:global_step/sec: 3.1451
# INFO:tensorflow:loss = 0.018834624, step = 1329 (31.797 sec)
# INFO:tensorflow:Saving checkpoints for 1347 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.12468275.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:25:54
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1347
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:25:58
# INFO:tensorflow:Saving dict for global step 1347: accuracy = 0.96710527, global_step = 1347, loss = 0.14457302
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1347
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1348 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.11280548, step = 1348
# INFO:tensorflow:global_step/sec: 3.14259
# INFO:tensorflow:loss = 0.019432114, step = 1448 (31.823 sec)
# INFO:tensorflow:Saving checkpoints for 1539 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.018803027.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-11-07:27:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1539
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-11-07:27:52
# INFO:tensorflow:Saving dict for global step 1539: accuracy = 0.9649123, global_step = 1539, loss = 0.12185952
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt-1539
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1540 into /hdd3/dhj_container/ICROS_vgg/kfold0811_3/model.ckpt.
# INFO:tensorflow:loss = 0.025534956, step = 1540
